# %% [markdown]
# <a href="https://colab.research.google.com/github/roggersanguzu/Machine-Learning/blob/main/ML_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mglearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 32.4 MB/s eta 0:00:00
# ...

# %%
import mglearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X,y=mglearn.datasets.make_wave(n_samples=40)
df=pd.DataFrame(np.c_[X,y],columns=["Features","Class"])
display(df)
# Out:
#     Features     Class
# 0  -0.752759 -0.448221
# 1   2.704286  0.331226
# 2   1.391964  0.779321
# 3   0.591951  0.034979
# 4  -2.063888 -1.387736
# 5  -2.064033 -2.471962
# 6  -2.651498 -1.527308
# 7   2.197057  1.494172
# 8   0.606690  1.000324
# 9   1.248435  0.229562
# 10 -2.876493 -1.059796
# 11  2.819459  0.778964
# 12  1.994656  0.754188
# 13 -1.725965 -1.513697
# 14 -1.909050 -1.673034
# 15 -1.899573 -0.904970
# 16 -1.174547  0.084485
# 17  0.148539 -0.527347
# 18 -0.408330 -0.541146
# 19 -1.252625 -0.340907
# 20  0.671117  0.217782
# 21 -2.163037 -1.124691
# 22 -1.247132  0.372991
# 23 -0.801829  0.097563
# 24 -0.263580 -0.986181
# 25  1.711056  0.966954
# 26 -1.801957 -1.134550
# 27  0.085407  0.697986
# 28  0.554487  0.436558
# 29 -2.721298 -0.956521
# 30  0.645269  0.035279
# 31 -1.976855 -2.085817
# 32 -2.609690 -0.474110
# 33  2.693313  1.537083
# 34  2.793792  0.868933
# 35  1.850384  1.876649
# 36 -1.172317  0.094526
# 37 -2.413967 -1.415024
# 38  1.105398  0.254389
# ...

# %%
plt.plot(X,y,"o")
plt.ylim(-3,3)
plt.xlabel("Features")
plt.ylabel("Class")
plt.grid()
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
reg=KNeighborsRegressor(n_neighbors=3)
reg.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred=reg.predict(X_test)
print("Precitions",y_pred)
# Out:
# Precitions [-0.05396539  0.35686046  1.13671923 -1.89415682 -1.13881398 -1.63113382
#   0.35686046  0.91241374 -0.44680446 -1.13881398]

# %%
reg.score(X_test,y_test)
# Out:
# 0.8344172446249605
