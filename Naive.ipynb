# %% [markdown]
# <a href="https://colab.research.google.com/github/roggersanguzu/ipynbs/blob/main/Naive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# %%
cancer=load_breast_cancer()
X_train,X_test,y_train,y_test=train_test_split(cancer.data,cancer.target,random_state=42)

# %%
model=GaussianNB().fit(X_train,y_train)
print("Accuracy on Training Set: ",model.score(X_train,y_train))
print("Accuracy on Test Set: ",model.score(X_test,y_test))
# Out:
# Accuracy on Training Set:  0.9366197183098591
# Accuracy on Test Set:  0.958041958041958

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
cancer=load_breast_cancer()
X_train,X_test,y_train,y_test=train_test_split(cancer.data,cancer.target,random_state=42)
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
